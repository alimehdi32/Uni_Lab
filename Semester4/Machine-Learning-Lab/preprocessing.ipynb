# %%
import pandas as pd
import numpy as np

# %%
student_data = {
"Student ID":[101,203,150,402,118,101,399,250,311,178,402,299,187,188,189,190,191,192,193,194,
None,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,
215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,
235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,
255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,
275,276,277,278,279],

"Age":[18,19,20,21,None,18,200,22,23,19,21,20,18,19,22,21,20,None,23,19,
45,18,19,None,21,20,22,23,19,18,17,21,20,None,19,18,200,23,22,21,
20,None,19,18,21,22,23,19,18,None,17,20,21,22,23,19,18,20,21,22,
23,None,18,19,20,21,22,23,19,18,20,21,22,None,19,18,20,21,22,
23,19,None,20,21,22,23,19,18,20,21,22,23,None,19,18,20,21,22,
23,19,18,20,None],

"Internal Marks":[45,50,None,38,41,45,999,47,35,None,42,30,55,None,40,41,20,44,39,1000,
45,50,38,41,None,47,35,42,30,55,40,41,20,None,39,45,50,38,41,47,
35,42,30,None,40,41,20,44,39,45,50,38,41,47,35,42,None,55,40,41,
20,44,39,45,50,None,41,47,35,42,30,55,40,None,20,44,39,45,50,38,
41,47,35,42,None,55,40,41,20,44,39,45,50,38,41,None,35,42,30,55,
40,41,20,44,None],

"External Marks":[70,None,65,60,58,70,5,62,None,59,61,55,75,None,64,58,0,63,66,200,
70,65,60,None,70,62,59,61,55,75,None,64,58,0,63,66,70,65,60,58,
70,None,59,61,55,75,64,58,0,63,66,70,65,None,58,70,62,59,61,55,
75,64,58,0,None,66,70,65,60,58,70,62,None,61,55,75,64,58,0,63,
66,None,65,60,58,70,62,59,61,None,75,64,58,0,63,66,70,65,None,58,
70,62,59,61,None],

"Attendance (%)":[85,90,None,88,92,85,300,87,80,None,91,75,89,None,93,92,-10,86,84,95,
85,90,88,None,92,85,87,80,91,75,None,93,92,86,84,95,85,90,None,88,
92,85,87,80,None,75,89,93,92,86,84,95,None,90,88,92,85,87,80,91,
75,89,None,93,92,86,84,95,85,90,88,None,85,87,80,91,75,89,93,None,
86,84,95,85,90,88,92,None,87,80,91,75,89,93,92,None,84,95,85,90,
88,92,85,None],

"Study Hours":[2,3.5,None,4,3,2,50,3.2,None,2.5,3.8,1,4.5,None,3.1,3,0,3.6,2.9,100,
2,3.5,4,None,3,2,3.2,2.5,3.8,1,None,3,0,3.6,2.9,2,3.5,None,4,3,
2,3.2,2.5,None,1,4.5,3.1,3,3.6,2.9,None,3.5,4,3,2,3.2,2.5,None,1,4.5,
3.1,3,0,3.6,None,2,3.5,4,3,2,3.2,None,3.8,1,4.5,3.1,3,3.6,None,
2.9,2,3.5,4,None,3,2,3.2,2.5,3.8,None,1,4.5,3.1,3,0,None,
3.6,2.9,2,3.5,None],

# "Grade":["B","A",None,"C","B","B","Z","A",None,"B","A","D","B",None,"C","B","F","A","B","A",
# "B","A","C",None,"B","A","D","B","C","B",None,"A","B","C","B","A",None,"D","B","C",
# "B","A","C","B",None,"A","D","B","C","B","A",None,"B","C","B","A","D","B",None,"C",
# "B","A","D","B","C",None,"A","B","C","B","A","D",None,"C","B","A","D","B","C",None,
# "B","A","C","B","D","B",None,"A","C","B","D","B","A",None,"C","B","A","D","B",None,
# "C","B","A","D","B"],

# "Department":["CS","IT",None,"CS","ECE","CS","Unknown","IT",None,"ME","CS","ECE","IT",None,"CS","ECE","CS","IT","ME","CS",
# "IT","CS","ECE",None,"CS","IT","ME","CS","ECE","IT",None,"CS","IT","ME","CS","ECE",None,"CS","IT","ME",
# "CS","ECE","IT","CS",None,"ME","CS","ECE","IT","CS","ME",None,"CS","IT","ECE","CS","ME","IT",None,"CS",
# "ECE","IT","CS","ME","IT",None,"CS","ECE","IT","CS","ME","IT",None,"CS","ECE","IT","CS","ME","IT",None,
# "CS","ECE","IT","CS","ME","IT",None,"CS","ECE","IT","CS","ME","IT",None,"CS","ECE","IT","CS",None,
# "ME","IT","CS","ECE","CS"],

"Project Score":[80,None,75,70,72,80,500,78,None,74,76,60,82,None,73,72,10,77,79,1000,
80,75,70,None,72,78,74,76,60,82,None,73,72,10,77,79,80,75,None,72,
78,74,76,None,82,73,72,10,77,79,None,75,70,72,78,74,None,60,82,73,
72,10,77,None,80,75,70,72,78,74,None,76,60,82,73,72,10,None,
77,79,80,75,None,72,78,74,76,60,None,82,73,72,10,77,None,
79,80,75,70,None]
}
max_len=max(len(v) for v in student_data.values())
for key,value in student_data.items():
    current_len=len(student_data[key])
    if current_len < max_len:
        student_data[key].extend([np.nan]*(max_len-current_len))



df=pd.DataFrame.from_dict(student_data)
print(df.shape)
print(df.head())
print(df.isnull().sum())

df=df.fillna(df.mean())
print(df.isnull().sum())
# Out:
# (105, 7)
#    Student ID   Age  Internal Marks  External Marks  Attendance (%)  \
# 0       101.0  18.0            45.0            70.0            85.0
# 1       203.0  19.0            50.0             NaN            90.0
# 2       150.0  20.0             NaN            65.0             NaN
# 3       402.0  21.0            38.0            60.0            88.0
# 4       118.0   NaN            41.0            58.0            92.0
#
#    Study Hours  Project Score
# 0          2.0           80.0
# 1          3.5            NaN
# 2          NaN           75.0
# 3          4.0           70.0
# 4          3.0           72.0
# Student ID         1
# Age               13
# Internal Marks    12
# External Marks    13
# Attendance (%)    15
# Study Hours       20
# Project Score     21
# dtype: int64
# Student ID        0
# Age               0
# Internal Marks    0
# External Marks    0
# Attendance (%)    0
# Study Hours       0
# Project Score     0
# dtype: int64

# %%
df['Student ID'].duplicated().sum()
# Out:
# np.int64(4)

# %%
df["Student ID"]=df["Student ID"].drop_duplicates()
print(df['Student ID'].duplicated().sum())
# Out:
# 3

# %%
df["Student ID"].drop_duplicates(inplace=True)
print(df['Student ID'].duplicated())
# Out:
# 3

# %%
df.drop_duplicates(subset=['Student ID'], inplace=True)
print(df['Student ID'].duplicated().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Student ID        1
# Age               0
# Internal Marks    0
# External Marks    0
# Attendance (%)    0
# Study Hours       0
# Project Score     0
# dtype: int64

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
print("First quartile (Q1):\n", q1)
print("Third quartile (Q3):\n", q3)
print("Interquartile range (IQR):\n", iqr)
# Out:
# First quartile (Q1):
#  Student ID        209.00
# Age                19.00
# Internal Marks     39.00
# External Marks     59.00
# Attendance (%)     85.00
# Study Hours         2.50
# Project Score      72.25
# Name: 0.25, dtype: float64
# Third quartile (Q3):
#  Student ID        258.00
# Age                23.00
# Internal Marks     50.00
# External Marks     65.00
# Attendance (%)     90.75
# Study Hours         4.50
# Project Score      82.00
# Name: 0.75, dtype: float64
# Interquartile range (IQR):
#  Student ID        49.00
# Age                4.00
# Internal Marks    11.00
# External Marks     6.00
# Attendance (%)     5.75
# Study Hours        2.00
# Project Score      9.75
# dtype: float64

# %%
print(f'Outliers:\n {df[(df < (q1 - 1.5 * iqr)) | (df > (q3 + 1.5 * iqr))]}')
# Out:
# Outliers:
#       Student ID  Age  Internal Marks  External Marks  Attendance (%)  \
# 0         101.0  NaN             NaN             NaN             NaN
# 1           NaN  NaN             NaN             NaN             NaN
# 2           NaN  NaN             NaN             NaN             NaN
# 3         402.0  NaN             NaN             NaN             NaN
# 4         118.0  NaN             NaN             NaN             NaN
# ..          ...  ...             ...             ...             ...
# 100         NaN  NaN             NaN             NaN             NaN
# 101         NaN  NaN             NaN             NaN             NaN
# 102         NaN  NaN            20.0             NaN             NaN
# 103         NaN  NaN             NaN             NaN             NaN
# 104         NaN  NaN             NaN             NaN             NaN
#
#      Study Hours  Project Score
# 0            NaN            NaN
# 1            NaN            NaN
# ...

# %%
print(f'Total Outliers:\n {df[(df < (q1 - 1.5 * iqr)) | (df > (q3 + 1.5 * iqr))].count()}')
# Out:
# Total Outliers:
#  Student ID         4
# Age                3
# Internal Marks     9
# External Marks    13
# Attendance (%)     8
# Study Hours        2
# Project Score      8
# dtype: int64

# %%
df=df[(df >= (q1 - 1.5 * iqr)) & (df <= (q3 + 1.5 * iqr))]

# %%
print(f'Total Outliers:\n {df[(df < (q1 - 1.5 * iqr)) | (df > (q3 + 1.5 * iqr))].count()}')
# Out:
# Total Outliers:
#  Student ID        0
# Age               0
# Internal Marks    0
# External Marks    0
# Attendance (%)    0
# Study Hours       0
# Project Score     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Student ID         5
# Age                3
# Internal Marks     9
# External Marks    13
# Attendance (%)     8
# Study Hours        2
# Project Score      8
# dtype: int64

# %%
max=df.max()
min=df.min()
print("Max values:\n",max)
print("\nMin values:\n",min)
# Out:
# Max values:
#  Student ID        311.000000
# Age                24.445652
# Internal Marks     61.172043
# External Marks     70.000000
# Attendance (%)     95.000000
# Study Hours         4.535294
# Project Score      86.166667
# dtype: float64
#
# Min values:
#  Student ID        150.0
# Age                17.0
# Internal Marks     30.0
# External Marks     55.0
# Attendance (%)     80.0
# Study Hours         0.0
# Project Score      60.0
# dtype: float64

# %%
df_min_max_scaled=(df-min)/(max-min)
print(df_min_max_scaled)
# Out:
#      Student ID       Age  Internal Marks  External Marks  Attendance (%)  \
# 0           NaN  0.134307        0.481200        1.000000        0.333333
# 1      0.329193  0.268613        0.641601        0.347101        0.666667
# 2      0.000000  0.402920        1.000000        0.666667        0.579259
# 3           NaN  0.537226        0.256640        0.333333        0.533333
# 4           NaN  1.000000        0.352880        0.200000        0.800000
# ..          ...       ...             ...             ...             ...
# 100    0.776398  0.134307        0.320800        1.000000        0.533333
# 101    0.782609  0.402920        0.352880        0.466667        0.800000
# 102    0.788820  1.000000             NaN        0.266667        0.333333
# 103    0.795031  1.000000        0.449120        0.400000        0.579259
# 104    0.801242  1.000000        1.000000        0.347101        0.579259
#
#      Study Hours  Project Score
# 0       0.440986       0.764331
# ...

# %%
df_min_max_scaled=df_min_max_scaled.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_min_max_scaled=df_min_max_scaled.dropna(inplace=True)
#       2 df_min_max_scaled.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
df_min_max_scaled.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_min_max_scaled.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
df_scaled=(df-min)/(max-min)
print(df_scaled)
# Out:
#      Student ID       Age  Internal Marks  External Marks  Attendance (%)  \
# 0           NaN  0.134307        0.481200        1.000000        0.333333
# 1      0.329193  0.268613        0.641601        0.347101        0.666667
# 2      0.000000  0.402920        1.000000        0.666667        0.579259
# 3           NaN  0.537226        0.256640        0.333333        0.533333
# 4           NaN  1.000000        0.352880        0.200000        0.800000
# ..          ...       ...             ...             ...             ...
# 100    0.776398  0.134307        0.320800        1.000000        0.533333
# 101    0.782609  0.402920        0.352880        0.466667        0.800000
# 102    0.788820  1.000000             NaN        0.266667        0.333333
# 103    0.795031  1.000000        0.449120        0.400000        0.579259
# 104    0.801242  1.000000        1.000000        0.347101        0.579259
#
#      Study Hours  Project Score
# 0       0.440986       0.764331
# ...

# %%
df_scaled.dropna()
# Out:
#      Student ID       Age  Internal Marks  External Marks  Attendance (%)  \
# 1      0.329193  0.268613        0.641601        0.347101        0.666667
# 2      0.000000  0.402920        1.000000        0.666667        0.579259
# 7      0.621118  0.671533        0.545360        0.466667        0.466667
# 8      1.000000  0.805839        0.160400        0.347101        0.000000
# 9      0.173913  0.268613        1.000000        0.266667        0.579259
# ..          ...       ...             ...             ...             ...
# 99     0.770186  0.268613        0.802001        0.200000        0.666667
# 100    0.776398  0.134307        0.320800        1.000000        0.533333
# 101    0.782609  0.402920        0.352880        0.466667        0.800000
# 103    0.795031  1.000000        0.449120        0.400000        0.579259
# 104    0.801242  1.000000        1.000000        0.347101        0.579259
#
#      Study Hours  Project Score
# 1       0.771725       1.000000
# ...

# %%
# Out:
# Max values:
#  Student ID        311.000000
# Age                24.445652
# Internal Marks     61.172043
# External Marks     70.000000
# Attendance (%)     95.000000
# Study Hours         4.535294
# Project Score      86.166667
# dtype: float64
#
# Min values:
#  Student ID        150.0
# Age                17.0
# Internal Marks     30.0
# External Marks     55.0
# Attendance (%)     80.0
# Study Hours         0.0
# Project Score      60.0
# dtype: float64
